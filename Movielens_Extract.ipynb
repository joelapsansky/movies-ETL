# %%
import pandas as pd

# %%
file_dir = 'C:/Users/joela/repos/vu-virt-data-pt-12-2020-u-b/movies-ETL'
kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 24639  False                   NaN      0
# 4385   False                   NaN      0
# 27878  False                   NaN      0
# 4709   False                   NaN      0
# 41237  False                   NaN      0
#
#                                                   genres  \
# 24639  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
# 4385                       [{'id': 18, 'name': 'Drama'}]
# 27878                      [{'id': 18, 'name': 'Drama'}]
# 4709   [{'id': 12, 'name': 'Adventure'}, {'id': 27, '...
# 41237                [{'id': 99, 'name': 'Documentary'}]
#
#                    homepage      id    imdb_id original_language  \
# 24639                   NaN   57563  tt0116866                en
# 4385                    NaN   75889  tt0095333                en
# 27878                   NaN  254721  tt3465916                de
# 4709                    NaN   31703  tt0080603                en
# 41237  http://riskfilm.org/  393561  tt4964772                en
#
#                     original_title  \
# 24639                   Level Five
# 4385   The House on Carroll Street
# 27878                     Kreuzweg
# 4709                    Death Ship
# 41237                         Risk
#
#                                                 overview  ... release_date  \
# 24639  The French computer programmer Laura inherits ...  ...   1997-02-19
# 4385   Emily Crane is fired after refusing to give na...  ...   1988-03-04
# 27878  Maria finds herself caught between two worlds....  ...   2014-03-20
# 4709   Survivors of a tragic shipping collision are r...  ...   1980-03-07
# 41237  Capturing the story of WikiLeaks founder Julia...  ...   2017-05-05
#
#       revenue runtime                                   spoken_languages  \
# 24639     0.0   106.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 4385      0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 27878     0.0   110.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 4709      0.0    91.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 41237     0.0    97.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 24639  Released                                                NaN
# 4385   Released                                                NaN
# 27878  Released                                                NaN
# 4709   Released  Those who survive the ghost ship are better of...
# 41237  Released  How much of your own life are you willing to risk
#
#                              title  video vote_average vote_count
# 24639                   Level Five  False          6.7        6.0
# 4385   The House on Carroll Street  False          5.4        8.0
# 27878        Stations of the Cross  False          7.2       38.0
# 4709                    Death Ship  False          5.5       27.0
# 41237                         Risk  False          6.9       10.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 8106033    83668     3555     4.0  1101686109
# 14204644  147577      593     3.0  1432638487
# 7568938    78247     1917     3.0  1136519592
# 10290139  106198      318     3.0   976064573
# 20955739  217757      262     3.0   839809165
