# %%
import pandas as pd

# %%
file_dir = 'C:/Users/joela/repos/vu-virt-data-pt-12-2020-u-b/movies-ETL'
kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection     budget  \
# 14167  False  {'id': 177467, 'name': 'Cloudy with a Chance o...  100000000
# 29501  False  {'id': 122661, 'name': 'Mardock Scramble Colle...          0
# 28331  False                                                NaN          0
# 27806  False                                                NaN          0
# 5156   False                                                NaN          0
#
#                                                   genres  \
# 14167  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 29501  [{'id': 53, 'name': 'Thriller'}, {'id': 16, 'n...
# 28331                                                 []
# 27806  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 5156   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
#
#                                            homepage      id    imdb_id  \
# 14167  http://www.cloudywithachanceofmeatballs.com/   22794  tt0844471
# 29501             http://m-scramble.jp/compression/   73529  tt1754177
# 28331                                           NaN   95108  tt0067987
# 27806                                           NaN  136742  tt2192200
# 5156                                            NaN   34276  tt0058100
#
#       original_language                     original_title  \
# 14167                en  Cloudy with a Chance of Meatballs
# 29501                ja                   マルドゥック・スクランブル 圧縮
# 28331                en                         Wild Honey
# 27806                en            Golfstrim pod Aysbergom
# 5156                 en              First Men in the Moon
#
#                                                 overview  ... release_date  \
# 14167  Inventor Flint Lockwood creates a machine that...  ...   2009-09-17
# 29501  Rune Ballot is a down-and-out teen prostitute ...  ...   2010-11-06
# 28331  Country girl comes to the big city, gets into ...  ...   1972-03-22
# 27806  Adam’s first wife Lilith is mentioned in the a...  ...   2012-06-26
# 5156   Based on the HG Wells story. The world is deli...  ...   1964-07-01
#
#            revenue runtime                          spoken_languages  \
# 14167  242988466.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 29501          0.0    69.0      [{'iso_639_1': 'ja', 'name': '日本語'}]
# 28331          0.0    95.0                                        []
# 27806          0.0   122.0  [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 5156           0.0   103.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 14167  Released                             Prepare to get served.
# 29501  Released                                                NaN
# 28331  Released  Who says love has to last? It just has to be g...
# 27806  Released                                                NaN
# 5156   Released    H.G. Wells' Astounding Adventure in Dynamation!
#
#                                          title  video vote_average vote_count
# 14167        Cloudy with a Chance of Meatballs  False          6.5     1799.0
# 29501  Mardock Scramble: The First Compression  False          7.1       23.0
# 28331                               Wild Honey  False          0.0        0.0
# 27806            Gulf Stream Under the Iceberg  False          3.5        2.0
# 5156                     First Men in the Moon  False          6.2       39.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 11372044  118036     1240     4.0  1044829212
# 24108486  250342      575     3.5  1111795217
# 732298      7438   103141     4.0  1490709957
# 1685984    17525     1911     3.0   980651873
# 17398555  180567     2423     4.0  1075248529
